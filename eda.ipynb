# %%
import pandas as pd
d = pd.read_csv(r"COVID clinical trials.csv", index_col ="Rank")

# %%
print(d)
# Out:
#        NCT Number                                              Title  \
# Rank
# 1     NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 2     NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 3     NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 4     NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 5     NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...           ...                                                ...
# 5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym                  Status         Study Results  \
# Rank
# ...

# %% [markdown]
# lets check the first five rows of data

# %%
d.head()
# Out:
#        NCT Number                                              Title  \
# Rank
# 1     NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 2     NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 3     NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 4     NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 5     NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#            Acronym                  Status         Study Results  \
# Rank
# 1      COVID-IDNow  Active, not recruiting  No Results Available
# 2         COVID-19      Not yet recruiting  No Results Available
# 3      TAC-COVID19              Recruiting  No Results Available
# 4         COVID-19  Active, not recruiting  No Results Available
# 5     TMF-COVID-19              Recruiting  No Results Available
#
#                                              Conditions  \
# Rank
# 1                                               Covid19
# ...

# %% [markdown]
# first fifteen rows

# %%
d.head(15)
# Out:
#        NCT Number                                              Title  \
# Rank
# 1     NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 2     NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 3     NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 4     NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 5     NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 6     NCT04516954          Convalescent Plasma for COVID-19 Patients
# 7     NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 8     NCT04634214  The Severity of COVID 19 in Diabetes and Non-d...
# 9     NCT04602884  Early Detection of COVID-19 Using Breath Analysis
# 10    NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
# 11    NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 12    NCT04412265          Frailty in Elderly Patients With COVID-19
# ...

# %% [markdown]
# info about the data

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5783 entries, 1 to 5783
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NCT Number               5783 non-null   object
#  1   Title                    5783 non-null   object
#  2   Acronym                  2480 non-null   object
#  3   Status                   5783 non-null   object
#  4   Study Results            5783 non-null   object
#  5   Conditions               5783 non-null   object
#  6   Interventions            4897 non-null   object
#  7   Outcome Measures         5748 non-null   object
#  8   Sponsor/Collaborators    5783 non-null   object
#  9   Gender                   5773 non-null   object
#  10  Age                      5783 non-null   object
#  11  Phases                   3322 non-null   object
#  12  Enrollment               5749 non-null   float64
#  13  Funded Bys               5783 non-null   object
# ...

# %% [markdown]
# shape of data

# %%
d.shape
# Out:
# (5783, 26)

# %% [markdown]
# Retrieve the Title and Status of the clinical trial with the NCT Number 'NCT04595136'.

# %%
second_trial= d[d['NCT Number']=="NCT04595136"]
title = second_trial['Title'].iloc[0] 
status = second_trial['Status'].iloc[0] 
print("title",title)
print("status",status)
# Out:
# title Study to Evaluate the Efficacy of COVID19-0001-USR in Patients With Mild/or Moderate COVID-19 Infection in Outpatient
# status Not yet recruiting

# %%
first_trial= d.iloc[0]
print(first_trial)
# Out:
# NCT Number                                                       NCT04785898
# Title                      Diagnostic Performance of the ID Now™ COVID-19...
# Acronym                                                          COVID-IDNow
# Status                                                Active, not recruiting
# Study Results                                           No Results Available
# Conditions                                                           Covid19
# Interventions               Diagnostic Test: ID Now™ COVID-19 Screening Test
# Outcome Measures           Evaluate the diagnostic performance of the ID ...
# Sponsor/Collaborators                  Groupe Hospitalier Paris Saint Joseph
# Gender                                                                   All
# Age                                18 Years and older   (Adult, Older Adult)
# Phases                                                        Not Applicable
# ...

# %%
third_trial=d[d["Status"]=="Recruiting"]
sponsor=third_trial['Sponsor/Collaborators'].iloc[0]
start_date=third_trial['Start Date'].iloc[0]
print("startdate",start_date)
print("sponsor",sponsor)
# Out:
# startdate May 7, 2020
# sponsor University of Milano Bicocca

# %%
dat=d.loc[[1,2, 3, 4, 5], ['Title', 'Conditions','Outcome Measures']]
print(dat)
# Out:
#                                                   Title  \
# Rank
# 1     Diagnostic Performance of the ID Now™ COVID-19...
# 2     Study to Evaluate the Efficacy of COVID19-0001...
# 3     Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 4     The Role of a Private Hospital in Hong Kong Am...
# 5            Maternal-foetal Transmission of SARS-Cov-2
#
#                                              Conditions  \
# Rank
# 1                                               Covid19
# 2                                  SARS-CoV-2 Infection
# 3                                               covid19
# 4                                                 COVID
# 5     Maternal Fetal Infection Transmission|COVID-19...
#
#                                        Outcome Measures
# Rank
# 1     Evaluate the diagnostic performance of the ID ...
# 2     Change on viral load results from baseline aft...
# 3     A qualitative analysis of parenchymal lung dam...
# ...

# %%
d.tail(3)
dat2=d.loc[[5481,5482,5483],['Completion Date','URL']]
print(dat2)
# Out:
#        Completion Date                                          URL
# Rank
# 5481    August 1, 2023  https://ClinicalTrials.gov/show/NCT03500328
# 5482         June 2023  https://ClinicalTrials.gov/show/NCT04422457
# 5483  October 31, 2020  https://ClinicalTrials.gov/show/NCT04536259

# %% [markdown]
# finding missing values

# %%
d.isnull()
# Out:
#       NCT Number  Title  Acronym  Status  Study Results  Conditions  \
# Rank
# 1          False  False    False   False          False       False
# 2          False  False    False   False          False       False
# 3          False  False    False   False          False       False
# 4          False  False    False   False          False       False
# 5          False  False    False   False          False       False
# ...          ...    ...      ...     ...            ...         ...
# 5779       False  False     True   False          False       False
# 5780       False  False     True   False          False       False
# 5781       False  False     True   False          False       False
# 5782       False  False    False   False          False       False
# 5783       False  False     True   False          False       False
#
#       Interventions  Outcome Measures  Sponsor/Collaborators  Gender  ...  \
# ...

# %% [markdown]
# adding missing values

# %%
d.isnull().sum()
# Out:
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %% [markdown]
# removing duplicates

# %%
duplicate_rows = d.duplicated().sum()
print(duplicate_rows)
# Out:
# 0

# %%
enrollment_threshold = 1000
studies_above_threshold = len(d[d['Enrollment'] > enrollment_threshold])

# %% [markdown]
# How many clinical trials have 'No Results Available

# %%
filtered_trials = d[(d['Status'] == 'Completed') | (d['Status'] == 'Recruiting')]
filtered_trial2=len(filtered_trials)
print("no of trials",filtered_trial2)
# Out:
# no of trials 3830

# %% [markdown]
# How many clinical trials are related to 'COVID-19'?

# %%
filtered_acronym=d[(d['Acronym'] == 'COVID-19')]
acr=len(filtered_acronym)
print(acr)
# Out:
# 47

# %% [markdown]
# How many clinical trials started after January 1, 2020?

# %%
Fil=d[(d["Start Date"]> "January 1,2020")]
fl=len(Fil)
print("no of enteries",fl)
# Out:
# no of enteries 3638
